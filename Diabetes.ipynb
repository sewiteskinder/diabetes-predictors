# %%
# %matplotlib notebook

# %%
#Importing dataset
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from warnings import filterwarnings
filterwarnings(action='ignore')

# %%
# Read CSV
df = pd.read_csv("Diabetes_Prediction_Clean.csv")
df
# Out:
#        Unnamed: 0  gender   age  hypertension  heart_disease smoking_history  \
# 0               0  Female  80.0             0              1           never
# 1               1    Male  28.0             0              0           never
# 2               2  Female  36.0             0              0         current
# 3               3    Male  76.0             1              1         current
# 4               4  Female  20.0             0              0           never
# ...           ...     ...   ...           ...            ...             ...
# 60175       60175  Female  26.0             0              0           never
# 60176       60176  Female  40.0             0              0           never
# 60177       60177    Male  66.0             0              0          former
# 60178       60178  Female  24.0             0              0           never
# 60179       60179  Female  57.0             0              0         current
#
#          bmi  HbA1c_level  blood_glucose_level  diabetes
# 0      25.19          6.6                  140         0
# 1      27.32          5.7                  158         0
# 2      23.45          5.0                  155         0
# 3      20.14          4.8                  155         0
# 4      27.32          6.6                   85         0
# ...      ...          ...                  ...       ...
# 60175  34.34          6.5                  160         0
# 60176  40.69          3.5                  155         0
# 60177  27.83          5.7                  155         0
# 60178  35.42          4.0                  100         0
# 60179  22.43          6.6                   90         0
#
# [60180 rows x 10 columns]

# %%
# The size of the data set was examined.
df.shape
# Out:
# (60180, 10)

# %%
#Feature information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60180 entries, 0 to 60179
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           60180 non-null  int64
#  1   gender               60180 non-null  object
#  2   age                  60180 non-null  float64
#  3   hypertension         60180 non-null  int64
#  4   heart_disease        60180 non-null  int64
#  5   smoking_history      60180 non-null  object
#  6   bmi                  60180 non-null  float64
#  7   HbA1c_level          60180 non-null  float64
#  8   blood_glucose_level  60180 non-null  int64
#  9   diabetes             60180 non-null  int64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 4.6+ MB

# %% [markdown]
# # Count Plot

# %%
# The classes of the outcome variable were examined.
df.diabetes.value_counts()
# Out:
# 0    53606
# 1     6574
# Name: diabetes, dtype: int64

# %%
# The distribution of the Outcome variable was examined.
df["diabetes"].value_counts()*100/len(df)
# Out:
# 0    89.076105
# 1    10.923895
# Name: diabetes, dtype: float64

# %%
# The distribution of the outcome variable in the data was examined and visualized.
f,ax=plt.subplots(1,2,figsize=(10,8))
df['diabetes'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Outcome')
ax[0].set_ylabel('')
sns.countplot(x ='diabetes', data = df, ax=ax[1])
ax[1].set_title('Outcome') 
# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# The histagram of the Age variable was reached.
df["age"].hist(edgecolor = "black")
plt.show()
